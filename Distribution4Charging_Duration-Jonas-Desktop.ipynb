# %% [markdown]
# # How to model the charging duration (or parking duration) for e-cars at supermarkets?
# According to **EHI-WHITEPAPER Elektromobilität im Handel 2023** the average charging times are
# | Duration  | Percentage    |
# | ---       | ---           |
# | max. 30 mins. | 15%       |
# | 30-60mins.    | 50%       |
# | 60-120mins.   | 31%       |
# | <120mins.     | 4%        |
#
# Based on these figures we can create some sample data to work with:
#
# Assumption 1: we take the midpoint per interval for our samples, e.g. we use 90mins for the interval from 60-120mins.
#
# Assumption 2: max. parking duration is 5 hours (--> midpoint = 210min)

# %%
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd

# %%
# 100 sample values following the distribution above
parking_duration_sample=[ \
    15, 15, 15, 15, 15, 15, 15, 15, 15, 15, \
    15, 15, 15, 15, 15, 45, 45, 45, 45, 45, \
    45, 45, 45, 45, 45, 45, 45, 45, 45, 45, \
    45, 45, 45, 45, 45, 45, 45, 45, 45, 45, \
    45, 45, 45, 45, 45, 45, 45, 45, 45, 45, \
    45, 45, 45, 45, 45, 45, 45, 45, 45, 45, \
    45, 45, 45, 45, 45, 90, 90, 90, 90, 90, \
    90, 90, 90, 90, 90, 90, 90, 90, 90, 90, \
    90, 90, 90, 90, 90, 90, 90, 90, 90, 90, \
    90, 90, 90, 90, 90, 90, 210, 210, 210, 210\
        ]

plt.hist(parking_duration_sample, bins = [0, 30, 60, 120, 300], alpha=0.5)
# plt.hist(parking_duration_sample, alpha=0.5)
plt.show()

# %% [markdown]
# With SciPy we can fit our sample data against various distributions. We will test 3 different distributions in the following:
# - Normal distribution (only for testing because we can see already from the histogram that our data is right skewed)
# - Lognormal distribution (used in HertleinEtAl_2023 for parking duration in inner-city garages)
# - Weibull distribution

# %%
bins=range(300)

# %%
# NORMAL
(mu, sigma) = stats.norm.fit(parking_duration_sample)
print(mu, sigma)
y = stats.norm.pdf(bins, mu, sigma)
# Out:
# 61.05 39.92677672940805

# %%
# lognormal
shape, loc, scale = stats.lognorm.fit(parking_duration_sample)
print(shape, loc, scale)
y2 = stats.lognorm.pdf(bins, shape, loc=loc, scale=scale)
# Out:
# 7.6614069750922775 14.999999999999998 3.04989671736646

# %%
# WEIBULL
a_out, Kappa_out, loc_out, Lambda_out = stats.exponweib.fit(parking_duration_sample)
y3=stats.exponweib.pdf(bins, a=a_out,c=Kappa_out,loc=loc_out,scale = Lambda_out)
print(a_out, Kappa_out, loc_out, Lambda_out)
# Out:
# 39.857766124920076 0.65117444343909 -20.724236876543387 8.472003942187907

# %%
# genarate random vars according to chosen distribution
r2 = stats.lognorm.rvs(shape, loc=loc, scale=scale, size=1000) 
df2 = pd.DataFrame(r2)
df2.describe()
# Out:
#                   0
# count  1.000000e+03
# mean   1.013308e+08
# std    2.685072e+09
# min    1.500000e+01
# 25%    1.501245e+01
# 50%    1.768000e+01
# 75%    5.554707e+02
# max    8.448369e+10

# %%
r3= stats.exponweib.rvs(a_out, Kappa_out, loc=loc_out, scale=Lambda_out, size=1000)
df3 = pd.DataFrame(r3)
df3.describe()
# Out:
#                  0
# count  1000.000000
# mean     60.967387
# std      37.647897
# min      -3.253598
# 25%      35.174242
# 50%      53.323366
# 75%      76.382863
# max     345.719611

# %% [markdown]
# The fitted lognormal distribution shows extremely large values which skrew up the whole distribution. Thus, with the provided data lognormal is not applicable or requires more parameter tuning!
#
# We do not see these outliers with Weibull but the minimum could be negative! These needs to be handled when used in the simulation model.

# %%
# Plotting
plt.plot(bins, y, 'r--')
#plt.plot(bins, y2, 'b.')
plt.plot(bins, y3, 'g--')
plt.hist(r3,density=True, bins='auto', histtype='stepfilled', alpha=0.5)
plt.hist(parking_duration_sample, bins = [0, 30, 60, 120, 300], density=True, alpha=0.3)

plt.show()

# %%
# CDF plotting
plt.plot(bins, stats.norm.cdf(bins, mu, sigma), label='Norm')
plt.plot(bins, stats.lognorm.cdf(bins, shape, loc=loc, scale=scale), label='Log-Normal')
plt.plot(bins, stats.exponweib.cdf(bins, a=a_out,c=Kappa_out,loc=loc_out,scale = Lambda_out), label='Weibull')

plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
# We have very limited data on the charging duration but can test in our simulation model a Weibull distribution for the duration with the following parameters
# $$a=39.857766124920076$$
# $$c=0.65117444343909$$
# $$loc=-20.724236876543387$$
# $$scale=8.472003942187907$$
#
# Additional exception handling is needed if negative values are returned!
#
# A charging duration for the next e-car can be computed with:

# %%
charge_time = stats.exponweib.rvs(a_out, Kappa_out, loc=loc_out, scale=Lambda_out, size=1)
print(charge_time)
# Out:
# [26.84688683]

# %% [markdown]
# With this returned numbers, we can run our simulation model and see the effect in the output

# %%
import importlib
# import random
import pandas as pd
# import matplotlib.dates as mdates
import json
import numpy as np
import matplotlib.pyplot as plt
import model_v2
importlib.reload(model_v2)

with open("settings_model_charging-time.json", "r") as f:
    settings = json.load(f)

df_results_returned = model_v2.simulation("settings_model_charging-time.json")
model_v2.plot(df_results_returned)
df_results_returned.describe()
# Out:
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 1
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 2
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 3
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 4
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 5
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 6
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 7
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 8
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 9
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 10
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 11
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 12
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 13
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 14
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 15
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 16
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 17
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 18
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 19
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 20
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 21
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 22
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 23
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 24
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 25
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 26
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 27
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 28
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 29
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 30
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 31
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# Alle Ladesäulen belegt. Abgewiesene EVs:  11
# Alle Ladesäulen belegt. Abgewiesene EVs:  12
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 32
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 33
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 34
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 35
# Alle Ladesäulen belegt. Abgewiesene EVs:  13
# Alle Ladesäulen belegt. Abgewiesene EVs:  14
# Alle Ladesäulen belegt. Abgewiesene EVs:  15
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 36
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 37
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 38
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 39
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 40
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 41
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 42
# Alle Ladesäulen belegt. Abgewiesene EVs:  16
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 43
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 44
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 45
# Alle Ladesäulen belegt. Abgewiesene EVs:  17
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 46
#        power_per_minute  number_cars_charging
# count       1441.000000           1441.000000
# mean         143.534007              2.185288
# std          117.142239              1.409178
# min            0.000000              0.000000
# 25%           53.111584              1.000000
# 50%          128.923458              2.000000
# 75%          202.773539              3.000000
# max          592.227064              4.000000

# %%
model_v2.plot(df_results_returned)

# %%
import seaborn as sns
sns.displot(np.asarray(df_results_returned['power_per_minute']), kind="ecdf")

# %% [markdown]
# ## Mehrere Durchläufe
#
# In folgendem Abschnitt wird die Simulation iterativ mehrere Male ausgeführt. Folglich kann ein gemittelter CDF-Plot zur Auswertung erstellt werden

# %%
df_results_10_runs = pd.DataFrame()

for i in range(10):
    df_results_returned = model_v2.simulation("settings_model_charging-time.json")
    df_results_10_runs[('load_run', i)] = df_results_returned.power_per_minute
# Out:
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 47
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 48
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 49
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 50
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 51
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 52
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 53
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 54
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 55
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 56
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 57
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 58
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 59
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 60
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 61
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 62
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 63
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 64
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 65
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 66
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 67
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 68
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 69
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 70
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 71
# Alle Ladesäulen belegt. Abgewiesene EVs:  11
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 72
# Alle Ladesäulen belegt. Abgewiesene EVs:  12
# Alle Ladesäulen belegt. Abgewiesene EVs:  13
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 73
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 74
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 75
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 76
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 77
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 78
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 79
# Alle Ladesäulen belegt. Abgewiesene EVs:  14
# Alle Ladesäulen belegt. Abgewiesene EVs:  15
# Alle Ladesäulen belegt. Abgewiesene EVs:  16
# Alle Ladesäulen belegt. Abgewiesene EVs:  17
# Alle Ladesäulen belegt. Abgewiesene EVs:  18
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 80
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 81
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 82
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 83
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 84
# Alle Ladesäulen belegt. Abgewiesene EVs:  19
# Alle Ladesäulen belegt. Abgewiesene EVs:  20
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 85
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 86
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 87
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 88
# Alle Ladesäulen belegt. Abgewiesene EVs:  21
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 89
# Alle Ladesäulen belegt. Abgewiesene EVs:  22
# Alle Ladesäulen belegt. Abgewiesene EVs:  23
# Alle Ladesäulen belegt. Abgewiesene EVs:  24
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 90
# Alle Ladesäulen belegt. Abgewiesene EVs:  25
# Alle Ladesäulen belegt. Abgewiesene EVs:  26
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 91
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 92
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 93
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 94
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 95
# Alle Ladesäulen belegt. Abgewiesene EVs:  27
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 96
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 97
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 98
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 99
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 100
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 101
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 102
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 103
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 104
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 105
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 106
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 107
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 108
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 109
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 110
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 111
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 112
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 113
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 114
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 115
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 116
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 117
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 118
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 119
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 120
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 121
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 122
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 123
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 124
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 125
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 126
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 127
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 128
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 129
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 130
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 131
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 132
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 133
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 134
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 135
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 136
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 137
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 138
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 139
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 140
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 141
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 142
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 143
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 144
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 145
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 146
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 147
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 148
# Alle Ladesäulen belegt. Abgewiesene EVs:  11
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 149
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 150
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 151
# Alle Ladesäulen belegt. Abgewiesene EVs:  12
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 152
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 153
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 154
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 155
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 156
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 157
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 158
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 159
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 160
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 161
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 162
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 163
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 164
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 165
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 166
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 167
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 168
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 169
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 170
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 171
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 172
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 173
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 174
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 175
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 176
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 177
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 178
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 179
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 180
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 181
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 182
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 183
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 184
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 185
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 186
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 187
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 188
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 189
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 190
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 191
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 192
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 193
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 194
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 195
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 196
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 197
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 198
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 199
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 200
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 201
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 202
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 203
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 204
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 205
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 206
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 207
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 208
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 209
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 210
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 211
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 212
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 213
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 214
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 215
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 216
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 217
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 218
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 219
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 220
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 221
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 222
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 223
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 224
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 225
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 226
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 227
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 228
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 229
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 230
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 231
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 232
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 233
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 234
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 235
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 236
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 237
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 238
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 239
# Alle Ladesäulen belegt. Abgewiesene EVs:  11
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 240
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 241
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 242
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 243
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 244
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 245
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 246
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 247
# Alle Ladesäulen belegt. Abgewiesene EVs:  12
# Alle Ladesäulen belegt. Abgewiesene EVs:  13
# Alle Ladesäulen belegt. Abgewiesene EVs:  14
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 248
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 249
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 250
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 251
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 252
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 253
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 254
# Alle Ladesäulen belegt. Abgewiesene EVs:  1
# Alle Ladesäulen belegt. Abgewiesene EVs:  2
# Alle Ladesäulen belegt. Abgewiesene EVs:  3
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 255
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 256
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 257
# Alle Ladesäulen belegt. Abgewiesene EVs:  4
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 258
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 259
# Alle Ladesäulen belegt. Abgewiesene EVs:  5
# Alle Ladesäulen belegt. Abgewiesene EVs:  6
# Alle Ladesäulen belegt. Abgewiesene EVs:  7
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 260
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs:
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 498
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 499
# Alle Ladesäulen belegt. Abgewiesene EVs:  8
# Alle Ladesäulen belegt. Abgewiesene EVs:  9
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 500
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 501
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 502
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 503
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 504
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 505
# Alle Ladesäulen belegt. Abgewiesene EVs:  10
# Alle Ladesäulen belegt. Abgewiesene EVs:  11
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 506
# Alle Ladesäulen belegt. Abgewiesene EVs:  12
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 507
# Alle Ladesäulen belegt. Abgewiesene EVs:  13
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 508
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 509
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 510
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 511
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 512
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 513
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 514
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 515
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 516
# Alle Ladesäulen belegt. Abgewiesene EVs:  14
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 517
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 518
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 519
# Alle Ladesäulen belegt. Abgewiesene EVs:  15
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 520
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 521
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 522
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 523
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 524
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 525
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 526
# Alle Ladesäulen belegt. Abgewiesene EVs:  16
# Alle Ladesäulen belegt. Abgewiesene EVs:  17
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 527
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 528
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 529
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 530
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 531
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 532
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 533
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 534
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 535
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 536
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 537
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 538
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 539
# Alle Ladesäulen belegt. Abgewiesene EVs:  18
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 540
# Alle Ladesäulen belegt. Abgewiesene EVs:  19
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 541
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 542
# Alle Ladesäulen belegt. Abgewiesene EVs:  20
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 543
# 'Tesla_Model_S-X_LR' charged. Anzahl geladener EVs: 544
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 545
# 'Porsche_Taycan' charged. Anzahl geladener EVs: 546
# 'FIAT_500e_Hatchback_2021' charged. Anzahl geladener EVs: 547
# 'VW_ID3_Pure' charged. Anzahl geladener EVs: 548
# 'Tesla_Model_3_LR' charged. Anzahl geladener EVs: 549

# %%
df_results_10_runs.describe()
# Out:
#        (load_run, 0)  (load_run, 1)  (load_run, 2)  (load_run, 3)  \
# count    1441.000000    1441.000000    1441.000000    1441.000000
# mean      197.843912     192.590478     174.335517     153.615072
# std       124.283375     122.243685     117.557488     131.116996
# min         0.000000       0.000000       0.000000       0.000000
# 25%       100.828673     104.600746      80.009042      43.436706
# 50%       174.011522     178.581987     149.218609     136.476868
# 75%       284.044099     276.778353     248.447327     238.067599
# max       667.104809     592.345489     580.636393     651.861400
#
#        (load_run, 4)  (load_run, 5)  (load_run, 6)  (load_run, 7)  \
# count    1441.000000    1441.000000    1441.000000    1441.000000
# mean      165.595289     184.150855     169.851857     187.589068
# std       107.001144     112.541326     104.207839     122.681207
# min         0.000000       0.000000       0.000000       0.000000
# 25%        81.794611      93.749178      95.862218      88.575471
# 50%       153.491335     174.410416     160.161486     176.751347
# 75%       232.674146     254.700369     232.547026     275.175173
# max       552.454751     596.199372     583.187521     546.125419
#
#        (load_run, 8)  (load_run, 9)
# count    1441.000000    1441.000000
# mean      146.180588     200.441904
# std       121.183323     118.405502
# min         0.000000       0.000000
# 25%        44.016323     114.376538
# 50%       123.816311     184.275547
# 75%       216.652428     273.932838
# max       557.702010     602.182708

# %% [markdown]
# Anschließend wird über die Durchläufe gemittelt der CDF geplottet

# %%
sns.displot(df_results_10_runs.values, kind="ecdf")
